# %% [markdown]
# # Netflix data analysis
#
#
# Netflix, Inc. is an American over-the-top content platform and production company headquartered in Los Gatos, California. Netflix was founded in 1997 by Reed Hastings and Marc Randolph in Scotts Valley, California

# %% [markdown]
# # Importing Libraries
# ## Loading Data

# %%
## Importing Libraries
## Loading Data 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd 
df = pd.read_csv("netflix_titles.csv")

# %% [markdown]
# ## Description of data

# %%
## Description of data
print(list(df.columns))
# Out:
# ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']

# %%
df.nunique()
# Out:
# show_id         7787
# type               2
# title           7787
# director        4049
# cast            6831
# country          681
# date_added      1565
# release_year      73
# rating            14
# duration         216
# listed_in        492
# description     7769
# dtype: int64

# %% [markdown]
# ## Number of rows

# %%
## Number of rows
len(df)
# Out:
# 7787

# %% [markdown]
# ## First five rows of dataset

# %%
## First five rows of dataset
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %% [markdown]
# ## Last five rows of dataset

# %%
df.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country          date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# ## Shape of dataset

# %%
## Shape of dataset
df.shape
# Out:
# (7787, 12)

# %% [markdown]
# # Data Cleaning
# ## Check for NULL values

# %%
## Data Cleaning
## Check for NULL values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## Check for unique values

# %%
## Chcek for unique values
df.nunique()
# Out:
# show_id         7787
# type               2
# title           7787
# director        4049
# cast            6831
# country          681
# date_added      1565
# release_year      73
# rating            14
# duration         216
# listed_in        492
# description     7769
# dtype: int64

# %% [markdown]
# ## Check for duplicate values

# %%
## Check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
## Subsetting dataset for type 'Movie'
df_movies_only = df[df['type'] == 'Movie']

# %%
## Selecting columns of interest
df_movies_col_subset = df_movies_only[['title','country','release_year','duration']]

# %%
## Printing first five items of new dataframe
df_movies_col_subset.head(5)
# Out:
#    title        country  release_year duration
# 1   7:19         Mexico          2016   93 min
# 2  23:59      Singapore          2011   78 min
# 3      9  United States          2009   80 min
# 4     21  United States          2008  123 min
# 6    122          Egypt          2019   95 min

# %% [markdown]
# ## Copy of dataset

# %%
## Copy of dataset
df1 = df.copy()

# %% [markdown]
# ## Shape of copied dataset

# %%
## Shape of copied dataset
df1.shape
# Out:
# (7787, 12)

# %% [markdown]
# ## Drop NULL values

# %%
## Drop NULL values
df1=df1.dropna()

# %%
df1.shape
# Out:
# (4808, 12)

# %% [markdown]
# ## Print first ten values of copied dataset

# %%
## Print first ten values of copied dataset
df1.head(10)
# Out:
#    show_id     type  title           director  \
# 1       s2    Movie   7:19  Jorge Michel Grau
# 2       s3    Movie  23:59       Gilbert Chan
# 3       s4    Movie      9        Shane Acker
# 4       s5    Movie     21     Robert Luketic
# 5       s6  TV Show     46        Serdar Akar
# 6       s7    Movie    122    Yasir Al Yasiri
# 7       s8    Movie    187     Kevin Reynolds
# 8       s9    Movie    706      Shravan Kumar
# 9      s10    Movie   1920       Vikram Bhatt
# 10     s11    Movie   1922       Zak Hilditch
#
#                                                  cast        country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# ...

# %% [markdown]
# ## Convert Date-time format

# %%
## Convert Date-time format
df1["date_added"] = pd.to_datetime(df1['date_added'])
df1['day_added'] = df1['date_added'].dt.day
df1['year_added'] = df1['date_added'].dt.year
df1['month_added']=df1['date_added'].dt.month
df1['year_added'].astype(int);
df1['day_added'].astype(int);

# %%
df1.head(10)
# Out:
#    show_id     type  title           director  \
# 1       s2    Movie   7:19  Jorge Michel Grau
# 2       s3    Movie  23:59       Gilbert Chan
# 3       s4    Movie      9        Shane Acker
# 4       s5    Movie     21     Robert Luketic
# 5       s6  TV Show     46        Serdar Akar
# 6       s7    Movie    122    Yasir Al Yasiri
# 7       s8    Movie    187     Kevin Reynolds
# 8       s9    Movie    706      Shravan Kumar
# 9      s10    Movie   1920       Vikram Bhatt
# 10     s11    Movie   1922       Zak Hilditch
#
#                                                  cast        country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# ...

# %% [markdown]
# # Data Visualisation
# ## Type -- Movie, TV Shows

# %%
## Data Visualisation
## Type -- Movie, TV Shows
sns.countplot(df['type'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Type')
# Out:
# Text(0.5, 1.0, 'Type')

# %%
sns.heatmap(df.isnull())

# %%
sns.pairplot(df1);

# %%
plt.hist(df1.corr());

# %%
f = sns.PairGrid(df)
f

# %% [markdown]
# ## Rating of shows and movies

# %%
# Rating of shows and movies
sns.countplot(df['rating'])
sns.countplot(df['rating']).set_xticklabels(sns.countplot(df['rating']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Rating')
# Out:
# Text(0.5, 1.0, 'Rating')

# %% [markdown]
# ## Relation between Type and Rating

# %%
## Relation between Type and Rating
plt.figure(figsize=(10,8))
sns.countplot(x='rating',hue='type',data=df)
plt.title('Relation between Type and Rating')
plt.show()

# %% [markdown]
# ## Pie Chart for type -- Movie and TV Shows

# %%
## Pie Chart for type -- Movie and TV Shows
labels = ['Movie', 'TV show']
size = df['type'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 2))
explode = [0, 0.1]
plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size,labels=labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Distribution of Type', fontsize = 25)
plt.legend()
plt.show()

# %% [markdown]
# ## Total frequency of both the types -- Movie and TV Shows

# %%
type_count=df[['type','show_id']].groupby('type').count().sort_values('type',ascending=True)
type_count
# Out:
#          show_id
# type
# Movie       5377
# TV Show     2410

# %% [markdown]
# ## longest and shortest movie as well as TV show

# %%
## longest and shortest movie 
longest_movie= df.loc[df.type=='Movie'].duration.str.replace('min','').astype(float).max()
shortest_movie= df.loc[df.type=='Movie'].duration.str.replace('min','').astype(float).min()
print(longest_movie, shortest_movie)
# Out:
# 312.0 3.0

# %%
## longest and shortest TV show
longest_tv_show=df[df.type=='TV Show'].duration.str.replace('min','').max()
shortest_tv_show=df[df.type=='TV Show'].duration.str.replace('min','').min()
print(longest_tv_show,shortest_tv_show)
# Out:
# 9 Seasons 1 Season

# %% [markdown]
# ## Most titles come under which rating

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='rating',data=df);

# %% [markdown]
# ## Pie Chart for Rating

# %%
## Pie Chart for Rating
df['rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %% [markdown]
# ## Histogram Distribution

# %%
plt.hist(df['release_year'])
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
fig = plt.figure(figsize=(12,60))
plt.scatter(df_movies_col_subset['release_year'], df_movies_col_subset['duration'])
plt.title('Movie duration by year of release')
plt.show()

# %% [markdown]
# ## Countries by the amount of the Production Content

# %%
filtered_countries = df.set_index('title').country.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
filtered_countries = filtered_countries[filtered_countries != 'Country Unavailable']
plt.figure(figsize=(13,7))
g = sns.countplot(y = filtered_countries, order=filtered_countries.value_counts().index[:15])
plt.title('Top fifteen countries contributor on Netflix!!')
plt.xlabel('Titles')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Top Directors on Netflix

# %%
## Top Directors on Netflix
filtered_directors = df[df.director != 'No Director'].set_index('title').director.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
plt.figure(figsize=(13,7))
plt.title('--Top ten directors based on number of titles--')
sns.countplot(y = filtered_directors, order=filtered_directors.value_counts().index[:10], palette='Blues')
plt.show()

# %% [markdown]
# ## Top genres on Netflix

# %%
## Top genres on Netflix
filtered_genres = df.set_index('title').listed_in.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
plt.figure(figsize=(10,10))
g = sns.countplot(y = filtered_genres, order=filtered_genres.value_counts().index[:20])
plt.title('///Top twenty genres on Netflix///')
plt.xlabel('Titles')
plt.ylabel('Genres')
plt.show()

# %% [markdown]
# ## Top Actors based on number of titles

# %%
## Top Actors based on number of titles
filtered_cast_shows = df[df.cast != 'No Cast'].set_index('title').cast.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
plt.figure(figsize=(13,7))
plt.title('Top ten actors based on the number of titles')
sns.countplot(y = filtered_cast_shows, order=filtered_cast_shows.value_counts().index[:10], palette='pastel')
plt.show()

# %% [markdown]
# ## Top ten years with most number of movies

# %%
a1 = df.title.groupby([df.type,df.release_year]).count()
a2 = a1[('Movie',)].sort_values(ascending =False)[:10]
plt.figure(figsize =(10,10))
sns.barplot(x = a2.index,y = a2.values)
plt.title('Top ten years with most number of movies')
# Out:
# Text(0.5, 1.0, 'Top ten years with most number of movies')

# %% [markdown]
# ## Top ten years with most number of TV Shows

# %%
a3 = a1[('TV Show',)].sort_values(ascending =False)[:10]
plt.figure(figsize =(10,10))
sns.barplot(x = a3.index,y = a3.values)
plt.title('Top ten years with most number of TV Shows')
# Out:
# Text(0.5, 1.0, 'Top ten years with most number of TV Shows')

# %% [markdown]
# ## Top 20 countries based on maximum number of TV shows on Netflix

# %%
plt.style.use("ggplot")
plt.figure(figsize=(12,6))
df[df["type"]=="TV Show"]["country"].value_counts()[:20].plot(kind="bar",color="mediumslateblue")
plt.title("%Top twenty countries in terms of maximum number of TV shows on netflix%")
# Out:
# Text(0.5, 1.0, '%Top twenty countries in terms of maximum number of TV shows on netflix%')

# %%
## release_year column -- Frequency of Movies which are released in different years
plt.style.use("ggplot")
plt.figure(figsize=(12,6))
df[df["type"]=="Movie"]["release_year"].value_counts()[:20].plot(kind="bar",color="darkorange")
plt.title("Frequency of Movies which are released in different years")
# Out:
# Text(0.5, 1.0, 'Frequency of Movies which are released in different years')

# %%
## Frequency of both TV Shows and movies which are released in different years
plt.style.use("ggplot")
plt.figure(figsize=(12,6))
df["release_year"].value_counts()[:20].plot(kind="bar",color="green")
plt.title("Frequency of both TV Shows and movies which are released in different years")
# Out:
# Text(0.5, 1.0, 'Frequency of both TV Shows and movies which are released in different years')

# %%
## listed_in column -- 20 most frequent genre for movie type for all the years
plt.style.use("ggplot")
plt.figure(figsize=(12,6))
df[df["type"]=="Movie"]["listed_in"].value_counts()[:20].plot(kind="barh",color="red")
plt.title("Twenty most frequent genre for movie type for all the years",size=18)
# Out:
# Text(0.5, 1.0, 'Twenty most frequent genre for movie type for all the years')

# %%
df[(df["listed_in"]=="Documentaries") & (df["type"]=="Movie")]["title"].sample()
# Out:
# 3236    Jugaad
# Name: title, dtype: object

# %%
## listed_in column -- 20 most frequent genre for TV show type for all the years
plt.style.use("ggplot")
plt.figure(figsize=(11,6))
df[df["type"]=="TV Show"]["listed_in"].value_counts()[:20].plot(kind="barh",color="darkviolet")
plt.title("Twenty most frequent genre for TV show type for all the years",size=18)
# Out:
# Text(0.5, 1.0, 'Twenty most frequent genre for TV show type for all the years')

# %%
df[(df["listed_in"]=="Kids' TV") & (df["type"]=="TV Show")]["title"].sample(10)
# Out:
# 5897          Super Monsters Monster Pets
# 3580     LEGO Elves: Secrets of Elvendale
# 2467                        Goldie & Bear
# 1282            Charlie's Colorforms City
# 3979                   Masha and the Bear
# 4945        Power Rangers Super Megaforce
# 2446                  Go! Go! Cory Carson
# 735          Barbie Dreamhouse Adventures
# 1214    Care Bears: Welcome to Care-a-Lot
# 2765                Hogie the Globehopper
# Name: title, dtype: object

# %% [markdown]
# ## Category and Rating

# %%
plt.figure(figsize =(10,5))
sns.lineplot(x = df.rating.value_counts().index,y = df.rating.value_counts().values)
plt.title('Rating-type Distribution')
# Out:
# Text(0.5, 1.0, 'Rating-type Distribution')

# %%
x =df.listed_in.value_counts().sort_values(ascending =False)
x= x[:5]

# %%
plt.figure(figsize =(20,10))
x.plot()
plt.title('Top five Category Distribution!!!')
# Out:
# Text(0.5, 1.0, 'Top five Category Distribution!!!')

# %%
df.listed_in.value_counts()[:3]
# Out:
# Documentaries                   334
# Stand-Up Comedy                 321
# Dramas, International Movies    320
# Name: listed_in, dtype: int64

# %%
plt.figure(figsize = (10,15))
plt.subplot(3,1,1)
df[df['listed_in']== 'Documentaries'].rating.value_counts().plot(colormap='jet',title='Documentaries')
plt.subplot(3,1,2)
df[df['listed_in']== 'Stand-Up Comedy'].rating.value_counts().plot(colormap='prism_r',title = 'Stand-Up Comedy')
plt.subplot(3,1,3)
df[df['listed_in']== 'Dramas, International Movies'].rating.value_counts().plot(colormap='rainbow',title = 'Dramas, International Movies')

# %% [markdown]
# ## Content

# %%
## Content added per year
netflix_year = df1['year_added'].value_counts().to_frame().reset_index().rename(columns={'index': 'year','year_added':'count'})
netflix_year = netflix_year[netflix_year.year != 2020]
netflix_year
# Out:
#     year  count
# 0   2019   1337
# 2   2018   1114
# 3   2017    752
# 4   2016    207
# 5   2021     78
# 6   2015     50
# 7   2014     14
# 8   2011     13
# 9   2013      7
# 10  2012      3
# 11  2009      2
# 12  2010      1
# 13  2008      1

# %%
netflix_year2 = df1[['type','year_added']]
movie_year = netflix_year2[netflix_year2['type']=='Movie'].year_added.value_counts().to_frame().reset_index().rename(columns={'index': 'year','year_added':'count'})
movie_year = movie_year[movie_year.year != 2020]
show_year = netflix_year2[netflix_year2['type']=='TV Show'].year_added.value_counts().to_frame().reset_index().rename(columns={'index': 'year','year_added':'count'})
show_year = show_year[show_year.year != 2020]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=netflix_year, x='year', y='count')
sns.lineplot(data=movie_year, x='year', y='count')
sns.lineplot(data=show_year, x='year', y='count')
ax.set_xticks(np.arange(2008, 2020, 1))
plt.title("Total content added each year (up to 2019)")
plt.legend(['Total','Movie','TV Show'])
plt.ylabel("Releases")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ## International movies/TV shows

# %%
international_movies = df1[df1['listed_in'].str.contains('International Movies')]
intmov_year = international_movies['year_added'].value_counts().to_frame().reset_index().rename(columns={'index': 'year','year_added':'count'})
intmov_year = intmov_year[intmov_year.year != 2020]

international_shows = df1[df1['listed_in'].str.contains('International TV Shows')]
intshow_year = international_shows['year_added'].value_counts().to_frame().reset_index().rename(columns={'index': 'year','year_added':'count'})
intshow_year = intshow_year[intshow_year.year != 2020]

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=intmov_year, x='year', y='count')
sns.lineplot(data=intshow_year, x='year', y='count')
ax.set(xticks=np.arange(2008, 2020, 1))
plt.title("International content across all years (up to 2019)")
plt.legend(['International Movies','International TV Shows'])
plt.show()

# %%
intmov_month_year_df = international_movies.groupby('year_added')['month_added'].value_counts().unstack().fillna(0).T

fig, ax = plt.subplots(figsize=(11, 8))
sns.heatmap(intmov_month_year_df, linewidths=0.025, cmap="BuPu")
plt.title("International Movies Heatmap")
plt.ylabel("Month")
plt.xlabel("Year")
plt.show()

# %%
intsho_month_year_df = international_shows.groupby('year_added')['month_added'].value_counts().unstack().fillna(0).T

fig, ax = plt.subplots(figsize=(11, 8))
sns.heatmap(intsho_month_year_df, linewidths=0.025, cmap="BuPu")
plt.title("International TV Shows Heatmap")
plt.ylabel("Month")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # Conclusion:
# We can see that a good amount of international movies and TV shows were added over the years as part of Netflix's global expansion. The company took certain approaches in their marketing strategy to break into new markets around the world.  Netflix had about 158 million subscribers worldwide with 60 million from the US and almost 98 million internationally.
#
#
#
#
# -After the analysis we concluded that Netflix has more movies than TV shows.
# -Most of the content on netflix is rated TV-MA.
# -Majority of content is added by United States.
# -Size of netflix content has been significantly increase over the last 10 years.
# -One of the famous directors on netflix are "Raul Campos Jan Suter" -- directed 17+ movie or tv show.
# -Most preferred genre is International

# %% [markdown]
# # Thank you
# Urjita Saxena ( EDU-1469721DS-URJ-328 )
